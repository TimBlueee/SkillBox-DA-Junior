# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import csv
import json

# %%
clients = pd.read_excel('CASE_CLIENTS.xlsx')
contracts = pd.read_excel('CASE_CONTRACTS.xlsx')
losses = pd.read_excel('CASE_LOSSES.xlsx')
exp_group = pd.read_excel('experiment_group.xlsx')

# %%
r = requests.get('https://cbr.ru/scripts/XML_daily.asp?date_req=03/02/2024')

# %%
with open ('cbr.xml', 'w') as f:
    f.write(r.text)

# %%
def export_xml_to_csv_func():
    parser = ET.XMLParser(encoding="UTF-8")
    tree = ET.parse('cbr.xml', parser=parser)
    root = tree.getroot()

    with open('cbr.csv', 'w') as csv_file:
        writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        for Valute in root.findall('Valute'):
            NumCode = Valute.find('NumCode').text
            CharCode = Valute.find('CharCode').text
            Nominal = Valute.find('Nominal').text
            Name = Valute.find('Name').text
            Value = Valute.find('Value').text
            writer.writerow([root.attrib['Date']] + [Valute.attrib['ID']] + [NumCode] + [CharCode] + [Nominal] +
                            [Name] + [Value.replace(',', '.')])

# %%
export_xml_to_csv_func()

# %%
df = pd.read_csv('cbr.csv', header=None)
df.head()
# Out:
#             0        1    2    3    4  \
# 0  03.02.2024   R01010   36  AUD    1
# 1  03.02.2024  R01020A  944  AZN    1
# 2  03.02.2024   R01035  826  GBP    1
# 3  03.02.2024   R01060   51  AMD  100
# 4  03.02.2024  R01090B  933  BYN    1
#
#                                           5         6
# 0                      Австралийский доллар   59.8101
# 1                     Азербайджанский манат   53.3309
# 2  Фунт стерлингов Соединенного королевства  114.9783
# 3                          Армянских драмов   22.4412
# 4                         Белорусский рубль   28.2324

# %%
rate_df = df.rename(columns={
    0: 'rate_dt',
    2: 'currency_id',
    3: 'currency_cd',
    4: 'nominal_qty',
    6: 'currency_rate'})[['rate_dt', 'currency_id', 'currency_cd', 'nominal_qty', 'currency_rate']]
rate_df = rate_df[rate_df['currency_cd'] == 'USD']
rate_df.head()
# Out:
#        rate_dt  currency_id currency_cd  nominal_qty  currency_rate
# 13  03.02.2024          840         USD            1        90.6626

# %%
merged_data = pd.merge(contracts, clients, on='client_id')
merged_data = pd.merge(merged_data, losses, on='client_id')
merged_data = pd.merge(merged_data, exp_group, on='client_id')
merged_data = pd.concat([merged_data, rate_df], ignore_index=True)
merged_data.head(47)
# Out:
#      contract_id     contract_num                      product_name  \
# 0   2.111956e+08  ТТЕ7227715*****      Страхование путешественников
# 1   2.113238e+08  БТАСЕ27153*****      Страхование путешественников
# 2   2.115958e+09  ТБАТМСЛЕ47*****  Страхование путешественников USD
# 3   2.116118e+09  ДСЖ-5/1539*****      Страхование путешественников
# 4   2.116191e+09  ИТЕ7 67777*****      Страхование путешественников
# 5   2.121233e+08  ДСЖ-5/1539*****      Страхование путешественников
# 6   2.121754e+08  ТМГО5Е7 № *****      Страхование путешественников
# 7   2.123544e+08  ТТЕ7227715*****      Страхование путешественников
# 8   2.124545e+08  ТТЕ7227778*****      Страхование путешественников
# 9   2.126338e+08  ДСЖ-5/1539*****      Страхование путешественников
# 10  2.126380e+08  ТТЕ7227715*****      Страхование путешественников
# 11  2.127587e+08  ДСЖ-5/1539*****      Страхование путешественников
# 12  2.128336e+08  БАЕАМСТЕ35*****      Страхование путешественников
# 13  2.128898e+08  ТТЕ7227777*****      Страхование путешественников
# 14  2.129222e+08  ДСЖ-5/1539*****      Страхование путешественников
# 15  2.129436e+07  ДСЖ-5/1539*****  Страхование путешественников USD
# 16  2.132617e+08  ТТЕ7227715*****      Страхование путешественников
# 17  2.132923e+08  ДСЖ-5/1539*****      Страхование путешественников
# 18  2.133949e+08  БТАСЕ475 -*****      Страхование путешественников
# 19  2.135193e+08  ТТЕ7227715*****      Страхование путешественников
# 20  2.135712e+08  БТАСЕ273 -*****      Страхование путешественников
# 21  2.136154e+08  ДСЖ-5/1539*****      Страхование путешественников
# 22  2.136212e+08  ИТЕ7 67777*****      Страхование путешественников
# 23  2.136334e+08  ТМГО5Е7 № *****      Страхование путешественников
# 24  2.136495e+08  БАЕАМСТЕ35*****      Страхование путешественников
# 25  2.136755e+08  ДСЖ-5/1539*****      Страхование путешественников
# 26  2.138123e+08  ДСЖ-5/1539*****      Страхование путешественников
# 27  2.139536e+08  ТТЕ7227715*****      Страхование путешественников
# 28  2.141159e+08  ДСЖ-5/1539*****      Страхование путешественников
# 29  2.142614e+08  ТТЕ7227779*****      Страхование путешественников
# 30  2.143123e+08  ТМГО5Е7 № *****      Страхование путешественников
# 31  2.143139e+08  ТТЕ7227778*****      Страхование путешественников
# 32  2.143389e+08  ТТЕ7227715*****      Страхование путешественников
# 33  2.143713e+08  ДСЖ-5/1539*****      Страхование путешественников
# 34  2.144968e+08  ДСЖ-5/1539*****      Страхование путешественников
# 35  2.145533e+08  ЦТТЕЕ774 7*****      Страхование путешественников
# 36  2.145965e+08  ДСЖ-5/1539*****      Страхование путешественников
# 37  2.147325e+09  ДСЖ-5/1539*****      Страхование путешественников
# 38  2.164636e+09  ДСЖ-5/1539*****      Страхование путешественников
# 39  2.164657e+09  ТТЕ7227715*****      Страхование путешественников
# 40  2.164896e+09  ДСЖ-5/1539*****      Страхование путешественников
# 41  2.164961e+09  ДСЖ-5/1539*****      Страхование путешественников
# 42  2.164984e+09  ДСЖ-5/1539*****      Страхование путешественников
# 43  2.165183e+09  БАТАМСТЕ35*****      Страхование путешественников
# 44  2.165228e+09  ДСЖ-5/1539*****      Страхование путешественников
# 45           NaN              NaN                               NaN
#
#        client_id contract_status     currency_name  duration         country  \
# 0   1.000071e+10       Действует  Российский рубль      10.0          Турция
# 1   1.000147e+08       Действует  Российский рубль      10.0          Турция
# 2   1.000579e+09       Действует        Доллар США      14.0             США
# 3   1.000655e+10       Действует  Российский рубль      10.0          Турция
# 4   1.000661e+10       Действует  Российский рубль      10.0          Турция
# 5   1.001092e+09       Действует  Российский рубль      14.0          Турция
# 6   1.001199e+09       Действует  Российский рубль      14.0          Турция
# 7   1.001932e+08       Действует  Российский рубль      15.0          Турция
# 8   1.003457e+10       Действует  Российский рубль      30.0          Турция
# 9   1.004167e+10       Действует  Российский рубль     365.0          Турция
# 10  1.004172e+09       Действует  Российский рубль     365.0          Турция
# 11  1.004948e+10       Действует  Российский рубль     365.0          Турция
# 12  1.004971e+09       Действует  Российский рубль     365.0          Турция
# 13  1.005388e+10       Действует  Российский рубль      13.0          Турция
# 14  1.005431e+08       Действует  Российский рубль      13.0          Турция
# 15  1.014449e+10       Действует        Доллар США      12.0             США
# 16  1.006399e+08       Действует  Российский рубль      16.0          Турция
# 17  1.006558e+08       Действует  Российский рубль      16.0          Турция
# 18  1.009009e+09       Действует  Российский рубль      19.0          Турция
# 19  1.010518e+09       Действует  Российский рубль      22.0          Турция
# 20  1.010790e+07       Действует  Российский рубль      22.0         Армения
# 21  1.010955e+08       Действует  Российский рубль      23.0       Казахстан
# 22  1.010959e+10       Действует  Российский рубль      23.0          Египет
# 23  1.011049e+09       Действует  Российский рубль      23.0          Грузия
# 24  1.011175e+09       Действует  Российский рубль      24.0        Германия
# 25  1.011199e+10       Действует  Российский рубль      25.0             ОАЭ
# 26  1.011884e+10       Действует  Российский рубль      28.0         Таиланд
# 27  1.013970e+10       Действует  Российский рубль       7.0         Таиланд
# 28  1.014634e+10       Действует  Российский рубль       7.0       Индонезия
# 29  1.015155e+10       Действует  Российский рубль       7.0         Армения
# 30  1.015459e+09       Действует  Российский рубль       7.0          Египет
# 31  1.015459e+09       Действует  Российский рубль       7.0         Таиланд
# 32  1.015972e+10       Действует  Российский рубль       7.0       Аргентина
# 33  1.016096e+07       Действует  Российский рубль       7.0      Узбекистан
# 34  1.016491e+10       Действует  Российский рубль      14.0     Азербайджан
# 35  1.016619e+10       Действует  Российский рубль      14.0        Беларусь
# 36  1.016648e+08       Действует  Российский рубль      14.0  Великобритания
# 37  1.016874e+10       Действует  Российский рубль      14.0          Канада
# 38  1.116320e+10       Действует  Российский рубль      14.0        Германия
# 39  1.860164e+09       Действует  Российский рубль      14.0        Германия
# 40  1.000484e+09       Действует  Российский рубль      14.0         Франция
# 41  1.000740e+10       Действует  Российский рубль      14.0         Армения
# 42  1.000777e+08       Действует  Российский рубль      14.0     Азербайджан
# 43  1.001063e+10       Действует  Российский рубль      14.0      Узбекистан
# 44  1.001117e+10       Действует  Российский рубль      14.0      Узбекистан
# 45           NaN             NaN               NaN       NaN             NaN
#
#       price  insurance_amount  ... loss_id                    loss_name  \
# 0    1644.0         3000000.0  ...     1.0  Оказание медицинской помощи
# 1    1644.0         3000000.0  ...     2.0  Оказание медицинской помощи
# 2      77.0          100000.0  ...    45.0  Оказание медицинской помощи
# 3    1644.0         3000000.0  ...     3.0  Оказание медицинской помощи
# 4    1644.0         3000000.0  ...     4.0  Оказание медицинской помощи
# 5    2301.0         3000000.0  ...     5.0  Оказание медицинской помощи
# 6    2301.0         3000000.0  ...     6.0  Оказание медицинской помощи
# 7    2466.0         3000000.0  ...     7.0  Оказание медицинской помощи
# 8    4932.0         3000000.0  ...     8.0  Оказание медицинской помощи
# 9   60000.0         3000000.0  ...     9.0  Оказание медицинской помощи
# 10  60000.0         3000000.0  ...    10.0  Оказание медицинской помощи
# 11  60000.0         3000000.0  ...    11.0  Оказание медицинской помощи
# 12  60000.0         3000000.0  ...    12.0  Оказание медицинской помощи
# 13   2137.0         3000000.0  ...    13.0  Оказание медицинской помощи
# 14   2137.0         3000000.0  ...    14.0  Оказание медицинской помощи
# 15     33.0           50000.0  ...    44.0  Оказание медицинской помощи
# 16   2630.0         3000000.0  ...    15.0  Оказание медицинской помощи
# 17   4384.0         5000000.0  ...    16.0  Оказание медицинской помощи
# 18   5205.0         5000000.0  ...    17.0  Оказание медицинской помощи
# 19   6027.0         5000000.0  ...    18.0  Оказание медицинской помощи
# 20   6027.0         5000000.0  ...    19.0  Оказание медицинской помощи
# 21   6301.0         5000000.0  ...    20.0  Оказание медицинской помощи
# 22   6301.0         5000000.0  ...    21.0  Оказание медицинской помощи
# 23   6301.0         5000000.0  ...    22.0  Оказание медицинской помощи
# 24   6575.0         5000000.0  ...    23.0  Оказание медицинской помощи
# 25   6849.0         5000000.0  ...    24.0  Оказание медицинской помощи
# 26   7671.0         5000000.0  ...    25.0  Оказание медицинской помощи
# 27   1918.0         5000000.0  ...    26.0  Оказание медицинской помощи
# 28   1918.0         5000000.0  ...    27.0  Оказание медицинской помощи
# 29   1918.0         5000000.0  ...    28.0  Оказание медицинской помощи
# 30   1918.0         5000000.0  ...    29.0  Оказание медицинской помощи
# 31   1918.0         5000000.0  ...    30.0  Оказание медицинской помощи
# 32   1918.0         5000000.0  ...    31.0  Оказание медицинской помощи
# 33   1918.0         5000000.0  ...    32.0  Оказание медицинской помощи
# 34   3836.0         5000000.0  ...    33.0  Оказание медицинской помощи
# 35   3836.0         5000000.0  ...    34.0  Оказание медицинской помощи
# 36   3836.0         5000000.0  ...    35.0  Оказание медицинской помощи
# 37   3836.0         5000000.0  ...    36.0  Оказание медицинской помощи
# 38   3836.0         5000000.0  ...    37.0  Оказание медицинской помощи
# 39   3836.0         5000000.0  ...    38.0  Оказание медицинской помощи
# 40   3836.0         5000000.0  ...    39.0  Оказание медицинской помощи
# 41   3836.0         5000000.0  ...    40.0  Оказание медицинской помощи
# 42   3836.0         5000000.0  ...    41.0  Оказание медицинской помощи
# 43   3836.0         5000000.0  ...    42.0  Оказание медицинской помощи
# 44   3836.0         5000000.0  ...    43.0  Оказание медицинской помощи
# 45      NaN               NaN  ...     NaN                          NaN
#
#    loss_payout_amt    group   experiment_id     rate_dt currency_id  \
# 0         100000.0  control  policy_pricing         NaN         NaN
# 1          50000.0  control  policy_pricing         NaN         NaN
# 2          20000.0     test  policy_pricing         NaN         NaN
# 3          30000.0  control  policy_pricing         NaN         NaN
# 4          70000.0  control  policy_pricing         NaN         NaN
# 5          60000.0  control  policy_pricing         NaN         NaN
# 6          50000.0  control  policy_pricing         NaN         NaN
# 7         100000.0  control  policy_pricing         NaN         NaN
# 8          50000.0  control  policy_pricing         NaN         NaN
# 9          20000.0  control  policy_pricing         NaN         NaN
# 10        100000.0     test  policy_pricing         NaN         NaN
# 11        300000.0     test  policy_pricing         NaN         NaN
# 12         30000.0     test  policy_pricing         NaN         NaN
# 13         50000.0  control  policy_pricing         NaN         NaN
# 14         40000.0  control  policy_pricing         NaN         NaN
# 15         30000.0     test  policy_pricing         NaN         NaN
# 16        150000.0     test  policy_pricing         NaN         NaN
# 17         50000.0  control  policy_pricing         NaN         NaN
# 18         90000.0     test  policy_pricing         NaN         NaN
# 19         50000.0     test  policy_pricing         NaN         NaN
# 20         20000.0     test  policy_pricing         NaN         NaN
# 21         50000.0     test  policy_pricing         NaN         NaN
# 22        100000.0  control  policy_pricing         NaN         NaN
# 23         50000.0     test  policy_pricing         NaN         NaN
# 24       1000000.0  control  policy_pricing         NaN         NaN
# 25       1500000.0     test  policy_pricing         NaN         NaN
# 26        200000.0      NaN  policy_pricing         NaN         NaN
# 27        250000.0  control  policy_pricing         NaN         NaN
# 28        150000.0  control  policy_pricing         NaN         NaN
# 29        100000.0  control  policy_pricing         NaN         NaN
# 30        100000.0  control  policy_pricing         NaN         NaN
# 31         50000.0  control  policy_pricing         NaN         NaN
# 32        200000.0  control  policy_pricing         NaN         NaN
# 33         50000.0  control  policy_pricing         NaN         NaN
# 34         80000.0  control  policy_pricing         NaN         NaN
# 35         50000.0     test  policy_pricing         NaN         NaN
# 36       1000000.0     test  policy_pricing         NaN         NaN
# 37        800000.0  control  policy_pricing         NaN         NaN
# 38        500000.0  control  policy_pricing         NaN         NaN
# 39        700000.0  control  policy_pricing         NaN         NaN
# 40       1300000.0  control  policy_pricing         NaN         NaN
# 41        100000.0  control  policy_pricing         NaN         NaN
# 42        100000.0  control  policy_pricing         NaN         NaN
# 43         50000.0  control  policy_pricing         NaN         NaN
# 44         80000.0  control  policy_pricing         NaN         NaN
# 45             NaN      NaN             NaN  03.02.2024       840.0
#
#     currency_cd nominal_qty currency_rate
# 0           NaN         NaN           NaN
# 1           NaN         NaN           NaN
# 2           NaN         NaN           NaN
# 3           NaN         NaN           NaN
# 4           NaN         NaN           NaN
# 5           NaN         NaN           NaN
# 6           NaN         NaN           NaN
# 7           NaN         NaN           NaN
# 8           NaN         NaN           NaN
# 9           NaN         NaN           NaN
# 10          NaN         NaN           NaN
# 11          NaN         NaN           NaN
# 12          NaN         NaN           NaN
# 13          NaN         NaN           NaN
# 14          NaN         NaN           NaN
# 15          NaN         NaN           NaN
# 16          NaN         NaN           NaN
# 17          NaN         NaN           NaN
# 18          NaN         NaN           NaN
# 19          NaN         NaN           NaN
# 20          NaN         NaN           NaN
# 21          NaN         NaN           NaN
# 22          NaN         NaN           NaN
# 23          NaN         NaN           NaN
# 24          NaN         NaN           NaN
# 25          NaN         NaN           NaN
# 26          NaN         NaN           NaN
# 27          NaN         NaN           NaN
# 28          NaN         NaN           NaN
# 29          NaN         NaN           NaN
# 30          NaN         NaN           NaN
# 31          NaN         NaN           NaN
# 32          NaN         NaN           NaN
# 33          NaN         NaN           NaN
# 34          NaN         NaN           NaN
# 35          NaN         NaN           NaN
# 36          NaN         NaN           NaN
# 37          NaN         NaN           NaN
# 38          NaN         NaN           NaN
# 39          NaN         NaN           NaN
# 40          NaN         NaN           NaN
# 41          NaN         NaN           NaN
# 42          NaN         NaN           NaN
# 43          NaN         NaN           NaN
# 44          NaN         NaN           NaN
# 45          USD         1.0       90.6626
#
# [46 rows x 25 columns]

# %%
merged_data.columns
# Out:
# Index(['contract_id', 'contract_num', 'product_name', 'client_id',
#        'contract_status', 'currency_name', 'duration', 'country', 'price',
#        'insurance_amount', 'last_name', 'first_name', 'middle_name', 'age',
#        'sex', 'loss_id', 'loss_name', 'loss_payout_amt', 'group',
#        'experiment_id', 'rate_dt', 'currency_id', 'currency_cd', 'nominal_qty',
#        'currency_rate'],
#       dtype='object')

# %%
merged_data = merged_data.drop(['contract_id', 'contract_num', 'product_name', 'client_id','contract_status', 'currency_name', 'duration', 'country','loss_id', 'loss_name', 'group',
                      'experiment_id', 'rate_dt', 'currency_id', 'nominal_qty'], axis = 1)

# %%
merged_data = merged_data[['last_name', 'first_name', 'middle_name', 'age', 'sex','price', 'insurance_amount', 'loss_payout_amt', 'currency_cd', 'currency_rate']]
merged_data.head()
# Out:
#   last_name first_name middle_name   age sex   price  insurance_amount  \
# 0    A*****     A*****      P*****  61.0   F  1644.0         3000000.0
# 1    А*****     Р*****      Э*****  67.0   F  1644.0         3000000.0
# 2    Г*****     В*****      Я*****  45.0   M    77.0          100000.0
# 3    Г*****     П*****         NaN  21.0   F  1644.0         3000000.0
# 4    Г*****     Ю*****      К*****  83.0   M  1644.0         3000000.0
#
#    loss_payout_amt currency_cd  currency_rate
# 0         100000.0         NaN            NaN
# 1          50000.0         NaN            NaN
# 2          20000.0         NaN            NaN
# 3          30000.0         NaN            NaN
# 4          70000.0         NaN            NaN

# %%
merged_data['currency_rate'] = merged_data['currency_rate'].replace(np.nan, 90.6626)
merged_data['currency_cd'] = merged_data['currency_cd'].replace(np.nan, 'USD')
merged_data.head()
# Out:
#   last_name first_name middle_name   age sex   price  insurance_amount  \
# 0    A*****     A*****      P*****  61.0   F  1644.0         3000000.0
# 1    А*****     Р*****      Э*****  67.0   F  1644.0         3000000.0
# 2    Г*****     В*****      Я*****  45.0   M    77.0          100000.0
# 3    Г*****     П*****         NaN  21.0   F  1644.0         3000000.0
# 4    Г*****     Ю*****      К*****  83.0   M  1644.0         3000000.0
#
#    loss_payout_amt currency_cd  currency_rate
# 0         100000.0         USD        90.6626
# 1          50000.0         USD        90.6626
# 2          20000.0         USD        90.6626
# 3          30000.0         USD        90.6626
# 4          70000.0         USD        90.6626

# %%
merged_data.loc[~merged_data.index.isin([2, 15]), 'price_usd'] = merged_data['price'] / merged_data['currency_rate']# Выбираем строки 2 и 15 и заменяем значение 'price_usd' только в оставшихся строках
merged_data.at[2, 'price_usd'] = 77
merged_data.at[15, 'price_usd'] = 33

merged_data.head()
# Out:
#   last_name first_name middle_name   age sex   price  insurance_amount  \
# 0    A*****     A*****      P*****  61.0   F  1644.0         3000000.0
# 1    А*****     Р*****      Э*****  67.0   F  1644.0         3000000.0
# 2    Г*****     В*****      Я*****  45.0   M    77.0          100000.0
# 3    Г*****     П*****         NaN  21.0   F  1644.0         3000000.0
# 4    Г*****     Ю*****      К*****  83.0   M  1644.0         3000000.0
#
#    loss_payout_amt currency_cd  currency_rate  price_usd
# 0         100000.0         USD        90.6626  18.133166
# 1          50000.0         USD        90.6626  18.133166
# 2          20000.0         USD        90.6626  77.000000
# 3          30000.0         USD        90.6626  18.133166
# 4          70000.0         USD        90.6626  18.133166

# %%
merged_data.loc[~merged_data.index.isin([2, 15]), 'insurance_amount_usd'] = merged_data['insurance_amount'] / merged_data['currency_rate']# Выбираем строки 2 и 15 и заменяем значение 'price_usd' только в оставшихся строках
merged_data.at[2, 'insurance_amount_usd'] = 100000
merged_data.at[15, 'insurance_amount_usd'] = 50000
merged_data.head()
# Out:
#   last_name first_name middle_name   age sex   price  insurance_amount  \
# 0    A*****     A*****      P*****  61.0   F  1644.0         3000000.0
# 1    А*****     Р*****      Э*****  67.0   F  1644.0         3000000.0
# 2    Г*****     В*****      Я*****  45.0   M    77.0          100000.0
# 3    Г*****     П*****         NaN  21.0   F  1644.0         3000000.0
# 4    Г*****     Ю*****      К*****  83.0   M  1644.0         3000000.0
#
#    loss_payout_amt currency_cd  currency_rate  price_usd  insurance_amount_usd
# 0         100000.0         USD        90.6626  18.133166          33089.719465
# 1          50000.0         USD        90.6626  18.133166          33089.719465
# 2          20000.0         USD        90.6626  77.000000         100000.000000
# 3          30000.0         USD        90.6626  18.133166          33089.719465
# 4          70000.0         USD        90.6626  18.133166          33089.719465

# %%
merged_data.loc[~merged_data.index.isin([2, 15]), 'loss_payout_amt_usd'] = merged_data['loss_payout_amt'] / merged_data['currency_rate']# Выбираем строки 2 и 15 и заменяем значение 'price_usd' только в оставшихся строках
merged_data.at[2, 'loss_payout_amt_usd'] = 20000
merged_data.at[15, 'loss_payout_amt_usd'] = 30000
merged_data.head()
# Out:
#   last_name first_name middle_name   age sex   price  insurance_amount  \
# 0    A*****     A*****      P*****  61.0   F  1644.0         3000000.0
# 1    А*****     Р*****      Э*****  67.0   F  1644.0         3000000.0
# 2    Г*****     В*****      Я*****  45.0   M    77.0          100000.0
# 3    Г*****     П*****         NaN  21.0   F  1644.0         3000000.0
# 4    Г*****     Ю*****      К*****  83.0   M  1644.0         3000000.0
#
#    loss_payout_amt currency_cd  currency_rate  price_usd  \
# 0         100000.0         USD        90.6626  18.133166
# 1          50000.0         USD        90.6626  18.133166
# 2          20000.0         USD        90.6626  77.000000
# 3          30000.0         USD        90.6626  18.133166
# 4          70000.0         USD        90.6626  18.133166
#
#    insurance_amount_usd  loss_payout_amt_usd
# 0          33089.719465          1102.990649
# 1          33089.719465           551.495324
# 2         100000.000000         20000.000000
# 3          33089.719465           330.897195
# 4          33089.719465           772.093454

# %%
#Создание новой колонки для суммы по убытку(Loss_payout_sum)
loss_payout_usd_sum = merged_data['loss_payout_amt_usd'].sum()
print("Сумма по убытку: ", loss_payout_usd_sum)
# Out:
# Сумма по убытку:  159968.1676898743

# %%
merged_data.to_excel('merged_file.xlsx', index=False)
